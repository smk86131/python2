# %%
class unit:
    def __init__(self, attack, speed, hitpoint):
        self.name = name
        self.attack = attack
        self.speed = speed
        self.hitpoint = hitpoint
        
    def targetAttack(self):
        print("공격력", self.attack, "로 공격합니다")
    def moving(self):
        print("속도", self.speed, "로 이동합니다")

# %%
class marine(unit):
    def stampack(self):
        if self.hitpoint <= 10:
            print("스팀팩을 사용할수없습니다")
            return
        self.hitpoint -= 10
        print("스팀팩을 사용합니다")
        print("현재체력: ",self.hitpoint)
        
    def moving(self):
        print("뛰어서 이동합니다")
        
marine1 = marine(6, 10, 40)

# %%
class zergling(unit):
    def adrenaline(self):
        if self.speed >= 4:
            print("더이상 아드레날린 진화를 할수없습니다")
            return
        self.speed +=2
        print("아드레날린 분비선 진화")
        print("공격속도: ",self.speed)
        
    def moving(self):
        print("달려서 이동합니다")
        
    def burrow(self):
        print("저글링이 잠복합니다")      
        
zergling1 = zergling(5, 2, 35)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-22f198e9ed62> in <module>
#      14         print("저글링이 잠복합니다")
#      15
# ---> 16 zergling1 = zergling(5, 2, 35)
#
# <ipython-input-1-50b96031ed19> in __init__(self, attack, speed, hitpoint)
#       1 class unit:
#       2     def __init__(self, attack, speed, hitpoint):
# ----> 3         self.name = name
#       4         self.attack = attack
#       5         self.speed = speed
#
# NameError: name 'name' is not defined
